# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import datetime

# %%
cab_df= pd.read_csv('Cab_Data.csv')
city_df=pd.read_csv('City.csv')
customer_df=pd.read_csv('Customer_ID.csv')
transaction_df=pd.read_csv('Transaction_ID.csv')

# %%
cab_df.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
cab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
cab_df.tail()
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
# 359391         12.76         191.58      177.6192

# %%
city_df.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
city_df.tail()
# Out:
#              City Population      Users
# 15  SACRAMENTO CA   545,776      7,044
# 16  PITTSBURGH PA   542,085      3,643
# 17  WASHINGTON DC   418,859    127,001
# 18   NASHVILLE TN   327,225      9,270
# 19      BOSTON MA   248,968     80,021

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
customer_df.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
customer_df.tail()
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
transaction_df.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
transaction_df.tail()
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card

# %%
transaction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
print("shape of cab_df",cab_df.shape)
print("shape of city_df",city_df.shape)
print("shape of customer",customer_df.shape)
print("shape of transation",transaction_df.shape)
# Out:
# shape of cab_df (359392, 7)
# shape of city_df (20, 3)
# shape of customer (49171, 4)
# shape of transation (440098, 3)

# %%
cab_df.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
city_df.describe()
# Out:
#                City   Population      Users
# count            20           20         20
# unique           20           20         20
# top     NEW YORK NY   8,405,837    302,149
# freq              1            1          1

# %%
customer_df.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
transaction_df.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
cab_df.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
city_df.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
customer_df.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
transaction_df.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
for col in cab_df.columns:
    if ' ' in col:
        cab_df = cab_df.rename(columns={col:col.replace(' ','_')})

# %%
cab_df.columns
# Out:
# Index(['Transaction_ID', 'Date_of_Travel', 'Company', 'City', 'KM_Travelled',
#        'Price_Charged', 'Cost_of_Trip'],
#       dtype='object')

# %%
for col in city_df.columns:
    if ' ' in col:
        city_df = city_df.rename(columns={col:col.replace(' ','_')})

# %%
city_df.columns
# Out:
# Index(['City', 'Population', 'Users'], dtype='object')

# %%
for col in customer_df.columns:
    if ' ' in col:
        customer_df = customer_df.rename(columns={col:col.replace(' ','_')})

# %%
customer_df.columns
# Out:
# Index(['Customer_ID', 'Gender', 'Age', 'Income_(USD/Month)'], dtype='object')

# %%
for col in transaction_df.columns:
    if ' ' in col:
        transaction_df = transaction_df.rename(columns={col:col.replace(' ','_')})

# %%
transaction_df.columns
# Out:
# Index(['Transaction_ID', 'Customer_ID', 'Payment_Mode'], dtype='object')

# %%
from datetime import datetime, timedelta
def to_date_format(n):
    date_str =(datetime(1899,12,30) + timedelta(n-1)).strftime("%d-%m-%Y")
    date_date =  datetime.strptime(date_str, "%d-%m-%Y")
    return date_date

# %%
cab_df['Date_of_Travel'] = cab_df['Date_of_Travel'].apply(lambda x:to_date_format(x))

# %%
cab_df.head()
# Out:
#    Transaction_ID Date_of_Travel   Company        City  KM_Travelled  \
# 0        10000011     2016-01-07  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-05  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-01  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-06  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-02  Pink Cab  ATLANTA GA          8.73
#
#    Price_Charged  Cost_of_Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
customer_df.head()
# Out:
#    Customer_ID Gender  Age  Income_(USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
months=[]
years =[]
for i in range(len(cab_df['Date_of_Travel'])):
    months.append(cab_df['Date_of_Travel'][i].month)
    years.append(cab_df['Date_of_Travel'][i].year)
cab_df['Month'] = months
cab_df['Year'] = years

cab_df.drop('Date_of_Travel', axis=1, inplace=True)

# %%
master_df = cab_df.merge(transaction_df, on= 'Transaction_ID').merge(customer_df,on='Customer_ID').merge(city_df,on='City')
missing_value = 0
for column in master_df.columns :
    missing_value += master_df[column].isna().sum() + master_df[column].isnull().sum()
print('master_df dataset has {} entries , {} features and {} missing values'.format(master_df.shape[0] ,master_df.shape[1] ,missing_value))
print("\nFeature's datatypes\n\n{}".format(master_df.dtypes))
master_df.head()
# Out:
# master_df dataset has 359392 entries , 15 features and 0 missing values
#
# Feature's datatypes
#
# Transaction_ID          int64
# Company                object
# City                   object
# KM_Travelled          float64
# Price_Charged         float64
# Cost_of_Trip          float64
# Month                   int64
# Year                    int64
# Customer_ID             int64
# Payment_Mode           object
# Gender                 object
# Age                     int64
# Income_(USD/Month)      int64
# Population             object
# Users                  object
# dtype: object
#    Transaction_ID     Company        City  KM_Travelled  Price_Charged  \
# 0        10000011    Pink Cab  ATLANTA GA         30.45         370.95
# 1        10351127  Yellow Cab  ATLANTA GA         26.19         598.70
# 2        10412921  Yellow Cab  ATLANTA GA         42.55         792.05
# 3        10000012    Pink Cab  ATLANTA GA         28.62         358.52
# ...

# %%
for column in master_df.columns:
    if ' ' in column:
        master_df = master_df.rename(columns={column:column.replace(' ','_')})
        
for column in ["Population","Users"] :
    
        master_df[column] = master_df[column].str.replace(',','')
        
master_df.head()
# Out:
#    Transaction_ID     Company        City  KM_Travelled  Price_Charged  \
# 0        10000011    Pink Cab  ATLANTA GA         30.45         370.95
# 1        10351127  Yellow Cab  ATLANTA GA         26.19         598.70
# 2        10412921  Yellow Cab  ATLANTA GA         42.55         792.05
# 3        10000012    Pink Cab  ATLANTA GA         28.62         358.52
# 4        10320494  Yellow Cab  ATLANTA GA         36.38         721.10
#
#    Cost_of_Trip  Month  Year  Customer_ID Payment_Mode Gender  Age  \
# 0      313.6350      1  2016        29290         Card   Male   28
# 1      317.4228      7  2018        29290         Cash   Male   28
# 2      597.4020     11  2018        29290         Card   Male   28
# 3      334.8540      1  2016        27703         Card   Male   27
# 4      467.1192      4  2018        27703         Card   Male   27
#
#    Income_(USD/Month) Population    Users
# 0               10813    814885    24701
# 1               10813    814885    24701
# ...

# %%
for column in ["Company", "City" , "Payment_Mode" , "Gender" ] :
    
        master_df[column] = master_df[column].astype('category')
        
        
for column in ["Population", "Users" ] :
    
        master_df[column] = master_df[column].astype('int64')
        
print("\nFeature's datatypes\n\n{}".format(master_df.dtypes))
# Out:
# Feature's datatypes
#
# Transaction_ID           int64
# Company               category
# City                  category
# KM_Travelled           float64
# Price_Charged          float64
# Cost_of_Trip           float64
# Month                    int64
# Year                     int64
# Customer_ID              int64
# Payment_Mode          category
# Gender                category
# Age                      int64
# Income_(USD/Month)       int64
# Population               int64
# Users                    int64
# dtype: object

# %%
pinkmaster_cab=master_df[master_df['Company']=='Pink Cab']
yellowmaster_cab=master_df[master_df['Company']=='Yellow Cab']
selected_columns = ['Transaction_ID','KM_Travelled','Price_Charged','Cost_of_Trip','Month','Year', 'Age' ,'Income_(USD/Month)', 'Population' , 'Users']

# %%
master_df.head()
# Out:
#    Transaction_ID     Company        City  KM_Travelled  Price_Charged  \
# 0        10000011    Pink Cab  ATLANTA GA         30.45         370.95
# 1        10351127  Yellow Cab  ATLANTA GA         26.19         598.70
# 2        10412921  Yellow Cab  ATLANTA GA         42.55         792.05
# 3        10000012    Pink Cab  ATLANTA GA         28.62         358.52
# 4        10320494  Yellow Cab  ATLANTA GA         36.38         721.10
#
#    Cost_of_Trip  Month  Year  Customer_ID Payment_Mode Gender  Age  \
# 0      313.6350      1  2016        29290         Card   Male   28
# 1      317.4228      7  2018        29290         Cash   Male   28
# 2      597.4020     11  2018        29290         Card   Male   28
# 3      334.8540      1  2016        27703         Card   Male   27
# 4      467.1192      4  2018        27703         Card   Male   27
#
#    Income_(USD/Month)  Population  Users
# 0               10813      814885  24701
# 1               10813      814885  24701
# ...

# %%
filter_pinkmaster_cab = pinkmaster_cab[selected_columns]
Pink_Cab_StatsInfo=filter_pinkmaster_cab.describe()
Pink_Cab_StatsInfo
# Out:
#        Transaction_ID  KM_Travelled  Price_Charged  Cost_of_Trip  \
# count    8.471100e+04  84711.000000   84711.000000  84711.000000
# mean     1.022394e+07     22.559917     310.800856    248.148682
# std      1.261782e+05     12.231092     181.995661    135.403345
# min      1.000001e+07      1.900000      15.600000     19.000000
# 25%      1.011014e+07     12.000000     159.970000    131.868000
# 50%      1.022590e+07     22.440000     298.060000    246.330000
# 75%      1.033642e+07     32.960000     441.505000    360.180000
# max      1.043762e+07     48.000000    1623.480000    576.000000
#
#               Month          Year           Age  Income_(USD/Month)  \
# count  84711.000000  84711.000000  84711.000000        84711.000000
# mean       7.816199   2017.046464     35.322414        15059.047137
# std        3.324986      0.800802     12.644780         7991.077762
# min        1.000000   2016.000000     18.000000         2000.000000
# ...

# %%
filter_yellowmaster_cab = yellowmaster_cab[selected_columns]
Yellow_Cab_StatsInfo=filter_yellowmaster_cab.describe()
Yellow_Cab_StatsInfo
# Out:
#        Transaction_ID   KM_Travelled  Price_Charged   Cost_of_Trip  \
# count    2.746810e+05  274681.000000  274681.000000  274681.000000
# mean     1.021978e+07      22.569517     458.181990     297.922004
# std      1.269829e+05      12.234298     288.386166     162.548986
# min      1.000038e+07       1.900000      20.730000      22.800000
# 25%      1.011084e+07      11.990000     226.680000     158.400000
# 50%      1.021987e+07      22.440000     425.060000     295.596000
# 75%      1.032939e+07      32.960000     633.880000     432.432000
# max      1.044011e+07      48.000000    2048.030000     691.200000
#
#                Month           Year            Age  Income_(USD/Month)  \
# count  274681.000000  274681.000000  274681.000000       274681.000000
# mean        7.414579    2017.040221      35.341112        15045.669817
# std         3.454863       0.801551      12.578625         7962.727062
# min         1.000000    2016.000000      18.000000         2000.000000
# ...

# %%
plot0 = master_df[master_df.Company=='Pink Cab'].groupby(['Month']).Transaction_ID.count()
plot0
# Out:
# Month
# 1      4825
# 2      3392
# 3      4228
# 4      4140
# 5      5023
# 6      5820
# 7      6585
# 8      8061
# 9      9647
# 10    10366
# 11    11324
# 12    11300
# Name: Transaction_ID, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=plot0.index,y=plot0.values)
plt.title('Travel frequency by Month (Pink Cab)')
plt.show()

# %%
plot1 = master_df[master_df.Company=='Yellow Cab'].groupby(['Month']).Transaction_ID.count()
plot1
# Out:
# Month
# 1     17468
# 2     14928
# 3     17516
# 4     17535
# 5     18809
# 6     18656
# 7     21074
# 8     24328
# 9     27356
# 10    29609
# 11    32609
# 12    34793
# Name: Transaction_ID, dtype: int64

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=plot1.index,y=plot1.values)
plt.title('Travel frequency by Month (Yellow Cab)')
plt.show()

# %%
#Yellow cab has higher travel frequency compared to pink cab in the month of december.

# %%
overall_distance = master_df['KM_Travelled'].describe()
pinkcab_distance = pinkmaster_cab['KM_Travelled'].describe()
yellowcab_distance = yellowmaster_cab['KM_Travelled'].describe()

# %%
df = pd.DataFrame({'Overall': overall_distance.values,
                  'pinkcab': pinkcab_distance.values,
                  'yellowcab': yellowcab_distance.values}, index= ['Count', 'Mean', 'Std. Dev.', 'Min', '25%', '50%', '75%', 'Max'])
df
# Out:
#                  Overall       pinkcab      yellowcab
# Count      359392.000000  84711.000000  274681.000000
# Mean           22.567254     22.559917      22.569517
# Std. Dev.      12.233526     12.231092      12.234298
# Min             1.900000      1.900000       1.900000
# 25%            12.000000     12.000000      11.990000
# 50%            22.440000     22.440000      22.440000
# 75%            32.960000     32.960000      32.960000
# Max            48.000000     48.000000      48.000000

# %%
ax = sns.distplot(pinkmaster_cab['KM_Travelled'], kde=False, color='pink', bins=70)
plt.title("Distribution of KM Travelled (Pink Cab)", fontsize=20, y=1.012)
plt.xlabel("KM Travelled", labelpad=15)
plt.ylabel("frequency", labelpad=15)
plt.show()

# %%
ax = sns.distplot(yellowmaster_cab['KM_Travelled'], kde=False, color='Yellow', bins=70)
plt.title("Distribution of KM Travelled (Yellow Cab)", fontsize=20, y=1.012)
plt.xlabel("KM Travelled", labelpad=15)
plt.ylabel("frequency", labelpad=15)
plt.show()

# %%
def showIQRstats(dataFrame_statsinfo,column_name):
    
    mean   = dataFrame_statsinfo[column_name][1]
    median = dataFrame_statsinfo[column_name][5]
    median_mean_ratio = median/mean
    Q1     = dataFrame_statsinfo[column_name][4]
    Q3     = dataFrame_statsinfo[column_name][6]
    IQR    = Q3-Q1
    upper_band = Q3 + 1.5*IQR
    lower_band = Q1 - 1.5*IQR
    
    print('\n\n' + "mean of : " + str(column_name) + " is " + str(mean) +
          '\n' + "median of : " + str(column_name) + " is " + str(median) +
          '\n' + "median/mean ratio of : " +  str(column_name) + " is " + str(median_mean_ratio) +
          '\n' + "Q1 value of : "  + str(column_name) + " is "  + str(Q1) +
          '\n' + "Q3 value of : "  + str(column_name) + " is "  + str(Q3) + 
          '\n' + "IQR value of : " + str(column_name) + " is " + str(IQR) + 
          '\n' + "Upper and Lower Limits of " + str(column_name) + " is "  + str((lower_band,upper_band))
         )
    
    return upper_band , lower_band

# %%
print('Statistical infos of Pink Cab Firm :')
for column_name in selected_columns :
    upper_band , lower_band = showIQRstats(Pink_Cab_StatsInfo , column_name)
    outliers = filter_pinkmaster_cab[(filter_pinkmaster_cab[column_name] < lower_band) | (filter_pinkmaster_cab[column_name] > upper_band)][column_name].values
    print('\n' + str(column_name) + " has " + str(len(outliers)) + " outliers : "    + str(outliers))
    print('\n\n**********************************************************\n')
# Out:
# Statistical infos of Pink Cab Firm :
#
#
# mean of : Transaction_ID is 10223938.220290164
# median of : Transaction_ID is 10225904.0
# median/mean ratio of : Transaction_ID is 1.0001922722602075
# Q1 value of : Transaction_ID is 10110143.5
# Q3 value of : Transaction_ID is 10336416.5
# IQR value of : Transaction_ID is 226273.0
# Upper and Lower Limits of Transaction_ID is (9770734.0, 10675826.0)
#
# Transaction_ID has 0 outliers : []
#
#
# **********************************************************
#
#
#
# mean of : KM_Travelled is 22.559916775861275
# median of : KM_Travelled is 22.44
# median/mean ratio of : KM_Travelled is 0.9946845204681968
# Q1 value of : KM_Travelled is 12.0
# Q3 value of : KM_Travelled is 32.96
# IQR value of : KM_Travelled is 20.96
# Upper and Lower Limits of KM_Travelled is (-19.44, 64.4)
#
# KM_Travelled has 0 outliers : []
#
#
# **********************************************************
#
#
#
# mean of : Price_Charged is 310.80085620521635
# ...

# %%
print('Statistical infos of Yellow Cab Firm :')
for column_name in selected_columns :
    upper_band , lower_band = showIQRstats(Pink_Cab_StatsInfo , column_name)
    outliers = filter_yellowmaster_cab[(filter_yellowmaster_cab[column_name] < lower_band) | (filter_yellowmaster_cab[column_name] > upper_band)][column_name].values
    print('\n' + str(column_name) + " has " + str(len(outliers)) + " outliers : "    + str(outliers))
    print('\n\n**********************************************************\n')
# Out:
# Statistical infos of Yellow Cab Firm :
#
#
# mean of : Transaction_ID is 10223938.220290164
# median of : Transaction_ID is 10225904.0
# median/mean ratio of : Transaction_ID is 1.0001922722602075
# Q1 value of : Transaction_ID is 10110143.5
# Q3 value of : Transaction_ID is 10336416.5
# IQR value of : Transaction_ID is 226273.0
# Upper and Lower Limits of Transaction_ID is (9770734.0, 10675826.0)
#
# Transaction_ID has 0 outliers : []
#
#
# **********************************************************
#
#
#
# mean of : KM_Travelled is 22.559916775861275
# median of : KM_Travelled is 22.44
# median/mean ratio of : KM_Travelled is 0.9946845204681968
# Q1 value of : KM_Travelled is 12.0
# Q3 value of : KM_Travelled is 32.96
# IQR value of : KM_Travelled is 20.96
# Upper and Lower Limits of KM_Travelled is (-19.44, 64.4)
#
# KM_Travelled has 0 outliers : []
#
#
# **********************************************************
#
#
#
# mean of : Price_Charged is 310.80085620521635
# ...

# %%
fig,axes = plt.subplots(2, 3, figsize=(25, 8), sharey=True)
fig.suptitle('Boxplot Distributions of the Variables')

sns.boxplot(ax=axes[0,0], x='KM_Travelled' ,        data=filter_pinkmaster_cab ).set_ylabel("Pink Cab")
sns.boxplot(ax=axes[0,1], x='Price_Charged'   ,     data=filter_pinkmaster_cab  ) .set_ylabel("Pink Cab")
sns.boxplot(ax=axes[0,2], x='Cost_of_Trip' ,        data=filter_pinkmaster_cab ).set_ylabel("Pink Cab")
sns.boxplot(ax=axes[1,0], x='KM_Travelled' ,        data=filter_yellowmaster_cab).set_ylabel("Yellow Cab")
sns.boxplot(ax=axes[1,1], x='Price_Charged'   ,     data=filter_yellowmaster_cab  ) .set_ylabel("Yellow Cab")
sns.boxplot(ax=axes[1,2], x='Cost_of_Trip' ,        data=filter_yellowmaster_cab ).set_ylabel("Yellow Cab")
# Out:
# Text(0, 0.5, 'Yellow Cab')

# %%
fig,axes = plt.subplots(2, 3, figsize=(25, 8), sharey=True)
fig.suptitle('Boxplot Distributions of the Variables')
sns.boxplot(ax=axes[0,0], x='Age' ,                 data=filter_pinkmaster_cab ).set_ylabel("Pink Cab")
sns.boxplot(ax=axes[0,1], x='Income_(USD/Month)' ,  data=filter_pinkmaster_cab  ) .set_ylabel("Pink Cab")
sns.boxplot(ax=axes[0,2], x='Population' ,          data=filter_pinkmaster_cab).set_ylabel("Pink Cab")
sns.boxplot(ax=axes[1,0], x='Age' ,                 data=filter_yellowmaster_cab).set_ylabel("Yellow Cab")
sns.boxplot(ax=axes[1,1], x='Income_(USD/Month)' ,  data=filter_yellowmaster_cab  ) .set_ylabel("Yellow Cab")
sns.boxplot(ax=axes[1,2], x='Population' ,          data=filter_yellowmaster_cab ).set_ylabel("Yellow Cab")
# Out:
# Text(0, 0.5, 'Yellow Cab')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 7))
sns.scatterplot(pinkmaster_cab['KM_Travelled'], pinkmaster_cab['Price_Charged'], ax=ax1)
ax1.set_title('Price vs Distance in Pink Cab', fontsize=20)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=0, fontsize=15)
sns.scatterplot(yellowmaster_cab['KM_Travelled'], yellowmaster_cab['Price_Charged'], ax=ax2)
ax2.set_title('Price vs Distance in Yellow Cab', fontsize=20)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=0, fontsize=15)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_1620/3130941639.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=0, fontsize=15)
# C:\Users\User\AppData\Local\Temp/ipykernel_1620/3130941639.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=0, fontsize=15)
# [Text(-10.0, 0, ''),
#  Text(0.0, 0, ''),
#  Text(10.0, 0, ''),
#  Text(20.0, 0, ''),
#  Text(30.0, 0, ''),
#  Text(40.0, 0, ''),
#  Text(50.0, 0, ''),
#  Text(60.0, 0, '')]

# %%
pinkmaster_cab['KM_Travelled'].corr(pinkmaster_cab['Price_Charged'])
# Out:
# 0.9277652782594858

# %%
yellowmaster_cab['KM_Travelled'].corr(yellowmaster_cab['Price_Charged'])
# Out:
# 0.8597086294478473

# %%
fig,axes = plt.subplots(1, 2, figsize=(25, 8), sharey=True)
fig.suptitle('Boxplot Distributions')
sns.scatterplot(ax=axes[0],data=master_df, x='KM_Travelled', y='Price_Charged' , hue="Company"  ).set_title("KM_Travelled  - Price_Charged")
sns.scatterplot(ax=axes[1],data=master_df, x='KM_Travelled', y='Cost_of_Trip' , hue="Company").set_title("KM_Travelled  - Cost_of_Trip")
# Out:
# Text(0.5, 1.0, 'KM_Travelled  - Cost_of_Trip')

# %%
fig,axes = plt.subplots(figsize=(16, 6), sharey=True)
fig.suptitle('Boxplot Distributions')
sns.scatterplot(data=master_df, x='Price_Charged', y='Cost_of_Trip' , hue="Company").set_title("Price_Charged - Cost_of_Trip")
# Out:
# Text(0.5, 1.0, 'Price_Charged - Cost_of_Trip')

# %%
fig,axes = plt.subplots(1, 2, figsize=(25, 8), sharey=True)
fig.suptitle('Pink Cab Firm Boxplot Distributions')
sns.scatterplot(ax=axes[0],data=master_df, x='Population', y='Price_Charged' , hue="Company").set_title("Population  - Price_Charged")
sns.scatterplot(ax=axes[1],data=master_df, x='Users', y='Price_Charged' , hue="Company").set_title("Users - Price_Charged")
# Out:
# Text(0.5, 1.0, 'Users - Price_Charged')

# %%
cov1  = np.cov(master_df['KM_Travelled'],master_df['Price_Charged'])[0][1]
cov2  = np.cov(master_df['KM_Travelled'],master_df['Cost_of_Trip'])[0][1]
cov3  = np.cov(master_df['Price_Charged'],master_df['Cost_of_Trip'])[0][1]
cov4  = np.cov(master_df['Users'],master_df['Population'])[0][1]
cov5  = np.cov(master_df['Population'],master_df['Price_Charged'])[0][1]
cov6  = np.cov(master_df['Users'],master_df['Price_Charged'])[0][1]

print('Covariance for  KM_Travelled - Price_Charged : '+ str(cov1))
print('Covariance for  KM_Travelled - Cost_of_Trip : '+ str(cov2))
print('Covariance for  Price_Charged - Cost_of_Trip : '+ str(cov3))
print('Covariance for  Users - Population : '+ str(cov4))
print('Covariance for  Population - Price_Charged : '+ str(cov5))
print('Covariance for  Users - Price_Charged : '+ str(cov6))
# Out:
# Covariance for  KM_Travelled - Price_Charged : 2805.307041308074
# Covariance for  KM_Travelled - Cost_of_Trip : 1897.7357483737053
# Covariance for  Price_Charged - Cost_of_Trip : 37272.94904600304
# Covariance for  Users - Population : 306082774585.4572
# Covariance for  Population - Price_Charged : 297071855.0581949
# Covariance for  Users - Price_Charged : 7777261.839139377

# %%
Pink_Cab_Corr = filter_pinkmaster_cab.corr()
plt.figure(figsize=(20,10))
sns.heatmap(Pink_Cab_Corr,annot=True,vmin=-1,vmax=1,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
Yellow_Cab_Corr = filter_yellowmaster_cab.corr()
plt.figure(figsize=(20,10))
sns.heatmap(Yellow_Cab_Corr,annot=True,vmin=-1,vmax=1,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
data = df.reset_index()
data = df.rename(columns={'Income_(USD/Month)':'Income'})
city_users = master_df.groupby('City').Users.count()
city_users
# Out:
# City
# ATLANTA GA         7557
# AUSTIN TX          4896
# BOSTON MA         29692
# CHICAGO IL        56625
# DALLAS TX          7017
# DENVER CO          3825
# LOS ANGELES CA    48033
# MIAMI FL           6454
# NASHVILLE TN       3010
# NEW YORK NY       99885
# ORANGE COUNTY      3982
# PHOENIX AZ         2064
# PITTSBURGH PA      1313
# SACRAMENTO CA      2367
# SAN DIEGO CA      20488
# SEATTLE WA         7997
# SILICON VALLEY     8519
# TUCSON AZ          1931
# WASHINGTON DC     43737
# Name: Users, dtype: int64

# %%
labs = city_users.index
vals = city_users.values
figp, axp = plt.subplots(figsize=(18,13))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')
plt.title('Users per City')
plt.show()

# %%
city_y = master_df[master_df.Company=='Yellow Cab'].groupby('City').Transaction_ID.count()
city_y
# Out:
# City
# ATLANTA GA         5795
# AUSTIN TX          3028
# BOSTON MA         24506
# CHICAGO IL        47264
# DALLAS TX          5637
# DENVER CO          2431
# LOS ANGELES CA    28168
# MIAMI FL           4452
# NASHVILLE TN       1169
# NEW YORK NY       85918
# ORANGE COUNTY      2469
# PHOENIX AZ         1200
# PITTSBURGH PA       631
# SACRAMENTO CA      1033
# SAN DIEGO CA       9816
# SEATTLE WA         5265
# SILICON VALLEY     4722
# TUCSON AZ          1132
# WASHINGTON DC     40045
# Name: Transaction_ID, dtype: int64

# %%
labs = city_y.index
vals = city_y.values
figp, axp = plt.subplots(figsize=(17,10))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')

plt.title('Transaction per City for Yellow Cab')
plt.show()

# %%
city_p = master_df[master_df.Company=='Pink Cab'].groupby('City').Transaction_ID.count()
city_p
# Out:
# City
# ATLANTA GA         1762
# AUSTIN TX          1868
# BOSTON MA          5186
# CHICAGO IL         9361
# DALLAS TX          1380
# DENVER CO          1394
# LOS ANGELES CA    19865
# MIAMI FL           2002
# NASHVILLE TN       1841
# NEW YORK NY       13967
# ORANGE COUNTY      1513
# PHOENIX AZ          864
# PITTSBURGH PA       682
# SACRAMENTO CA      1334
# SAN DIEGO CA      10672
# SEATTLE WA         2732
# SILICON VALLEY     3797
# TUCSON AZ           799
# WASHINGTON DC      3692
# Name: Transaction_ID, dtype: int64

# %%
labs = city_p.index
vals = city_p.values
figp, axp = plt.subplots(figsize=(17,10))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')

plt.title('Transaction per City for pink Cab')
plt.show()

# %%
gender_y=master_df[master_df.Company=='Yellow Cab'].groupby('Gender').Price_Charged.mean()
gender_y
# Out:
# Gender
# Female    454.571538
# Male      460.821326
# Name: Price_Charged, dtype: float64

# %%
labs = gender_y.index
vals = gender_y.values
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')

plt.title('Price Charged per Gender for Yellow Cab')
plt.show()

# %%
gender_cab=master_df.groupby(['Company','Gender']).Customer_ID.nunique()
gender_cab
# Out:
# Company     Gender
# Pink Cab    Female    14819
#             Male      17511
# Yellow Cab  Female    18394
#             Male      21502
# Name: Customer_ID, dtype: int64

# %%
labs = gender_cab.index
vals = gender_cab.values
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(vals , labels=labs, autopct='%1.1f%%',shadow=True, startangle=90,)
axp.axis('equal')

plt.title('Customer share per gender per cab')
plt.show()

# %%
pinkData = master_df[master_df['Company'] == 'Pink Cab']
yellowData =master_df[master_df['Company'] == 'Yellow Cab']

# %%
pay_cab=master_df.groupby(['Company','Payment_Mode']).count()
pay_cab
# Out:
#                          Transaction_ID    City  KM_Travelled  Price_Charged  \
# Company    Payment_Mode
# Pink Cab   Card                   50719   50719         50719          50719
#            Cash                   33992   33992         33992          33992
# Yellow Cab Card                  164785  164785        164785         164785
#            Cash                  109896  109896        109896         109896
#
#                          Cost_of_Trip   Month    Year  Customer_ID  Gender  \
# Company    Payment_Mode
# Pink Cab   Card                 50719   50719   50719        50719   50719
#            Cash                 33992   33992   33992        33992   33992
# Yellow Cab Card                164785  164785  164785       164785  164785
#            Cash                109896  109896  109896       109896  109896
#
#                             Age  Income_(USD/Month)  Population   Users  \
# Company    Payment_Mode
# ...

# %%
plot1 = cab_df[cab_df.Company=='Pink Cab'].groupby('Year').Transaction_ID.count()
plot2 = cab_df[cab_df.Company=='Yellow Cab'].groupby('Year').Transaction_ID.count()
plt.figure(figsize=(14,6))
ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot1.values, width=0.4, color='green', align='center',label='Pink Cab')
ax.bar(plot1.index+0.2, plot2.values, width=0.4, color='yellow', align='center',label='Yellow Cab')
plt.ylabel('No. of Transactions')
plt.xlabel('Year')
plt.legend()
plt.show()

# %%
plot1 = cab_df[cab_df.Company=='Pink Cab'].groupby('Year').Transaction_ID.count()
plot3 = cab_df[cab_df.Company=='Pink Cab'].groupby('Year').Price_Charged.mean()
plot4 = cab_df[cab_df.Company=='Pink Cab'].groupby('Year').Cost_of_Trip.mean()
plt.figure(figsize=(9,4))
ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot4.values, width=0.4, color='green', align='center',label='Cost of the Trip')
ax.bar(plot1.index+0.2, plot3.values, width=0.4, color='red', align='center',label='Price Charged')
plt.ylabel('Profit')
plt.xlabel('Year')
plt.title('Pink Cab', fontsize=20)
plt.legend()
plt.show()

# %%
plot1 = cab_df[cab_df.Company=='Yellow Cab'].groupby('Year').Transaction_ID.count()
plot3 = cab_df[cab_df.Company=='Yellow Cab'].groupby('Year').Price_Charged.mean()
plot4 = cab_df[cab_df.Company=='Yellow Cab'].groupby('Year').Cost_of_Trip.mean()
plt.figure(figsize=(9,4))
ax = plt.subplot(111)
ax.bar(plot1.index-0.2, plot4.values, width=0.4, color='red', align='center',label='Cost of the Trip')
ax.bar(plot1.index+0.2, plot3.values, width=0.4, color='green', align='center',label='Price Charged')
plt.ylabel('Profit')
plt.xlabel('Year')
plt.title('Yellow Cab', fontsize=20)
plt.legend()
plt.show()

# %%
master_df['Margins'] = (master_df['Price_Charged']-master_df['Cost_of_Trip'])

# %%
master_df.head()
# Out:
#    Transaction_ID     Company        City  KM_Travelled  Price_Charged  \
# 0        10000011    Pink Cab  ATLANTA GA         30.45         370.95
# 1        10351127  Yellow Cab  ATLANTA GA         26.19         598.70
# 2        10412921  Yellow Cab  ATLANTA GA         42.55         792.05
# 3        10000012    Pink Cab  ATLANTA GA         28.62         358.52
# 4        10320494  Yellow Cab  ATLANTA GA         36.38         721.10
#
#    Cost_of_Trip  Month  Year  Customer_ID Payment_Mode Gender  Age  \
# 0      313.6350      1  2016        29290         Card   Male   28
# 1      317.4228      7  2018        29290         Cash   Male   28
# 2      597.4020     11  2018        29290         Card   Male   28
# 3      334.8540      1  2016        27703         Card   Male   27
# 4      467.1192      4  2018        27703         Card   Male   27
#
#    Income_(USD/Month)  Population  Users  Profit_of_Trip   Margins
# 0               10813      814885  24701         57.3150   57.3150
# ...

# %%
df = master_df[['KM_Travelled','Price_Charged','Cost_of_Trip','Month','Year','Age','Income_(USD/Month)','Margins']]
df.corr()
# Out:
#                     KM_Travelled  Price_Charged  Cost_of_Trip     Month  \
# KM_Travelled            1.000000       0.835753      0.981848 -0.001773
# Price_Charged           0.835753       1.000000      0.859812 -0.059639
# Cost_of_Trip            0.981848       0.859812      1.000000 -0.008309
# Month                  -0.001773      -0.059639     -0.008309  1.000000
# Year                   -0.001094      -0.036903     -0.001766 -0.033169
# Age                    -0.000369      -0.003084     -0.000189 -0.002376
# Income_(USD/Month)     -0.000544       0.003228     -0.000633  0.000585
# Margins                 0.462768       0.864154      0.486056 -0.093886
#
#                         Year       Age  Income_(USD/Month)   Margins
# KM_Travelled       -0.001094 -0.000369           -0.000544  0.462768
# Price_Charged      -0.036903 -0.003084            0.003228  0.864154
# Cost_of_Trip       -0.001766 -0.000189           -0.000633  0.486056
# ...

# %%
a = master_df[(master_df.Gender=='Female')&(master_df.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = master_df[(master_df.Gender=='Male')&(master_df.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that there is a difference')
else:
    print('We accept null hypothesis that there is no difference')
    
print('P value is ', p_value)
# Out:
# 37480 47231
# We accept null hypothesis that there is no difference
# P value is  0.11515305900425798

# %%
master_df[master_df.Age<=50].groupby('Company').Margins.mean()
# Out:
# Company
# Pink Cab       62.765586
# Yellow Cab    161.081921
# Name: Margins, dtype: float64

# %%
master_df[master_df.Age>50].groupby('Company').Margins.mean()
# Out:
# Company
# Pink Cab       62.053044
# Yellow Cab    155.855885
# Name: Margins, dtype: float64

# %%
#Pink Cab
a = master_df[(master_df.Age<=50)&(master_df.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = master_df[(master_df.Age>50)&(master_df.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that theres a difference')
else:
    print('We accept null hypothesis that theres no difference')
    
print('P value is ', p_value)
# Out:
# 71228 13483
# We accept null hypothesis that theres no difference
# P value is  0.32817487547980695

# %%
#Yellow Cab
a = master_df[(master_df.Age<=50)&(master_df.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
b = master_df[(master_df.Age>50)&(master_df.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
print(a.shape[0],b.shape[0])

from scipy import stats
_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that theres a difference')
else:
    print('We accept null hypothesis that theres no difference')
    
print('P value is ', p_value)
# Out:
# 231480 43201
# We accept alternate hypothesis that theres a difference
# P value is  6.494256817799368e-09

# %%
#Pink Cab
a = master_df[(master_df.Payment_Mode=='Cash')&(master_df.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()
b = master_df[(master_df.Payment_Mode=='Card')&(master_df.Company=='Pink Cab')].groupby('Transaction_ID').Margins.mean()


_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that theres a difference')
else:
    print('We accept null hypothesis that theres no difference')
    
print('P value is ', p_value)
# Out:
# We accept null hypothesis that theres no difference
# P value is  0.7900465828793288

# %%
#Yellow Cab
a = master_df[(master_df.Payment_Mode=='Cash')&(master_df.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()
b = master_df[(master_df.Payment_Mode=='Card')&(master_df.Company=='Yellow Cab')].groupby('Transaction_ID').Margins.mean()


_, p_value = stats.ttest_ind(a.values,b=b.values,equal_var=True)
if(p_value<0.05):
    print('We accept alternate hypothesis that theres a difference')
else:
    print('We accept null hypothesis that theres no difference')
    
print('P value is ', p_value)
# Out:
# We accept null hypothesis that theres no difference
# P value is  0.2933060638298729
